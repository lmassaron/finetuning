# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lmassaron/finetuning/blob/main/chapter_09/listing_9.7.ipynb)

# %%
import sys
if 'google.colab' in sys.modules:
    # !pip install transformers peft vllm openai ollama lmcache

# %% [markdown]
# ### Listing 9.7: Interacting with the local llama-server via the OpenAI Python Client

# %%
from openai import OpenAI

client = OpenAI(base_url="http://localhost:8080/v1", api_key="not-needed")

response = client.chat.completions.create(
    model="local-model",  # any string; llama-server ignores this field
    messages=[{"role": "user", "content": "What is the KV cache?"}]
)
print(response.choices[0].message.content)
# Out:
# In Qwen, there's no official API for KV cache, but users can provide the URL of the KV cache to be executed.
